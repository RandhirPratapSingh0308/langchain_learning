# %%
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path='../.env')

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.tools import tool

@tool
def get_weather(location: str) -> str:
    """Get the weather at the location"""
    return f"It's sunny in {location}"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from langchain.tools import tool
#       2
#       3 @tool
#       4 def get_weather(location: str) -> str:
#
# ModuleNotFoundError: No module named 'langchain'

# %%
from langchain_groq import ChatGroq
from langgraph.prebuilt import create_react_agent

model = ChatGroq(model="qwen/qwen3.8-27b")

agent = create_react_agent(
    model=model,
    tools=[get_weather],
    prompt="you are a helpful assistant"
)

agent
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from langchain_groq import ChatGroq
#       2 from langgraph.prebuilt import create_react_agent
#       3
#       4 model = ChatGroq(model="qwen/qwen3.8-27b")
#
# ModuleNotFoundError: No module named 'langchain_groq'

# %%
response = agent.invoke({"messages": [{"role": "user", "content": "what is the weather like in bangalore"}]})
print(response["messages"][-1].content)
# Out:
# It's currently sunny in Bangalore.
