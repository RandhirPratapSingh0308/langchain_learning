# %%
import os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())

# Check that keys loaded properly
print("Tavily Key loaded:", os.getenv("TAVILY_API_KEY") is not None)
print("Groq Key loaded:", os.getenv("GROQ_API_KEY") is not None)

from langchain_groq import ChatGroq
model = ChatGroq(model="qwen/qwen3.8-27b")
# Out:
# Tavily Key loaded: True
# Groq Key loaded: True

# %%
from langchain_tavily import TavilySearch

tavily_search_tool = TavilySearch(
    max_results=5,
    topic="general"
)

tavily_search_tool.invoke("What is the current AI news")
# Out:
# {'query': 'What is the current AI news',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.artificialintelligence-news.com',
#    'title': 'AI News | Latest News | Insights Powering AI-Driven Business ...',
#    'content': 'October 30, 2025\n\n### Malaysia launches Ryt Bank, its first AI-powered bank\n\nFinance AI\n\nAugust 26, 2025\n\n### Google’s Veo 3 AI video creation tools are now widely available\n\nAI in Action\n\nJuly 29, 2025\n\n#### Computer Vision\n\n### Microsoft’s Majorana 2 quantum chip is also a case study for agentic AI in R&D\n\nInside AI\n\nJune 3, 2026\n\n### US and Japan announce sweeping AI and tech collaboration\n\nArtificial Intelligence\n\nApril 11, 2024\n\n### UK and Canada sign AI compute agreement [...] August 18, 2026\n\n### Okta targets AI agent token costs with MCP scoping\n\nData Engineering & MLOps\n\nAugust 13, 2026\n\n### Red Hat, NVIDIA, IBM back project turning AI policy into code\n\nGovernance, Regulation & Policy\n\nAugust 4, 2026\n\n#### Industries\n\n### NVIDIA Jetson Orin Nano 2 brings physical AI to drones and robots\n\nPhysical AI\n\nAugust 26, 2026\n\n### HoneyBook bets on agentic AI to streamline small business operations with its new Claude connector\n\nWorld of Work\n\nAugust 6, 2026 [...] January 8, 2026\n\n# On-Demand Webinar: AI Combined with Automation is the Perfect Marriage for Scalable, Intelligent Operations\n\nResource\n\nJanuary 6, 2026\n\n# On-Demand Webinar: DataOps Can Build the Foundation For Your Generative AI Ambitions\n\nResource\n\nDecember 11, 2025\n\n# On-Demand Webinar: From Complexity to Clarity: AI + Agility Layer for Intelligent Insurance\n\nResource\n\nDecember 11, 2025\n\n# On-Demand Webinar: Turning a Hacker’s Toolkit Against Them\n\n## Events\n\nView All Events',
#    'score': 0.78631157,
#    'raw_content': None,
#    'id': '1dc5d8-00'},
#   {'url': 'https://techcrunch.com/category/artificial-intelligence',
#    'title': 'AI News & Artificial Intelligence',
#    'content': '# AI\n\nNews coverage on artificial intelligence and machine learning tech, the companies building them, and the ethical issues AI raises today. This encompasses generative AI, including large language models, text-to-image and text-to-video models; speech recognition and generation; and predictive analytics.\n\nLast day to book an exhibit table is September 18. Don’t miss out on high-impact leads, investor access, and a brand spotlight in Disrupt’s Expo Hall.',
#    'score': 0.76152116,
#    'raw_content': None,
#    'id': '4e4ffa-01'},
#   {'url': 'https://www.wsj.com/tech/ai',
#    'title': 'Artificial Intelligence - Latest AI News and Analysis - WSJ.com',
#    'content': "David Wainer\n\nClothes are displayed on hangers at a Chinese fashion brand Shein pop-up store in Paris on May 4, 2023. - The Shein pop-up store is set to open for business from May 5 to 8. (Photo by Christophe ARCHAMBAULT / AFP) (Photo by CHRISTOPHE ARCHAMBAULT/AFP via Getty Images)\n\n### Fashion Giant Shein Raises $2 Billion but Lowers Valuation by a Third\n\nJing Yang\n\nEmily Oster, Professor of Economics, Brown University; Author\n\n### The Ways You Can Be a Better Parent\n\nOyin Adedoyin [...] Also, OpenAI disappoints some investors and shares of Unitree Robotics soar more than 600%.\n\nBy\n\nRisk Report: Pivotal Child Safety Trial Starts in California\n\nRisk and Compliance Journal\n\n### Risk Report: Pivotal Child Safety Trial Starts in California\n\nPlus: Disney sues FCC over license review, and Europe’s rivers are drying up, threatening its economy.\n\nBy\n\n2\n\nChinese Humanoid Robot Leader Soars in Market Debut Despite U.S. Ban\n\nTech [...] View All\n\nSenator Elizabeth Warren, a Democrat from Massachusetts, during a Senate Banking, Housing, and Urban Affairs Committee hearing in Washington, DC, US, on Thursday, May 18, 2023. Two senators on the committee say they have found flaws in regulators' oversight reviews before some of the recent bank failures, and are asking the president to appoint an independent investigator. Photographer: Al Drago/Bloomberg\n\n### Elizabeth Warren and the FTC Are the Least of Amgen’s Problems",
#    'score': 0.71948266,
#    'raw_content': None,
#    'id': 'ba4526-02'},
#   {'url': 'https://guides.library.georgetown.edu/ai/news',
#    'title': 'Artificial Intelligence (Generative) Resources: Latest News on AI',
#    'content': 'Formerly MIT Technology Review. Includes The Algorithm.\n VKTR: The Business of Enterprise AI This link opens in a new window  \n\n  "We give AI users and leaders at enterprises the practical examples, tools and knowledge they need to thrive in the fast-changing AI era... VKTR is produced by San Francisco, California-based Simpler Media Group, which also produces CMSWire..."\n\n## AI News from the New York Times, WSJ, and Washington Post (ProQuest)\n\nLoading ... [...] Skip to Main Content\n\n# Artificial Intelligence (Generative) Resources: Latest News on AI\n\n Home\n AI Fundamentals\n AI Tools for Research\n How to Craft Prompts\n Research Resources on AI\n Latest News on AI \n  + AI News from the New York Times, WSJ, and Washington Post (ProQuest)\n  + AI News in Education Periodicals (EBSCO)\n Ethics & AI\n Citing Generative AI\n AI, Authorship, & Copyright\n Campus Resources and Policies\n\n## Publications covering AI\n\n Technology Review This link opens in a new window [...] Loading ...\n\n## AI News in Education Periodicals (EBSCO)\n\nLoading ...\n\n << Previous: Research Resources on AI\n Next: Ethics & AI >>\n\n Last Updated: Sep 17, 2026 3:57 PM\n URL: \n Print Page;)\n\nLogin to LibApps\n\nReport a problem\n\nSubjects: \n\n Artificial Intelligence\n\nCreative Commons   This work is licensed under a Creative Commons Attribution NonCommercial 4.0 International License. | Details of our policy',
#    'score': 0.64826655,
#    'raw_content': None,
#    'id': '07ffd0-03'},
#   {'url': 'https://www.nbcnews.com/artificial-intelligence',
#    'title': 'Artificial intelligence news: Chat AI, ChatGPT, AI generator, AI Chatbot and Bard | NBC News',
#    'content': '1d ago\n\n## OpenAI says AI models went rogue during testing, triggering ‘unprecedented’ breach at startup\n\nThe incident signals that AI’s expanding capabilities are already fueling the security threat experts long feared.\n\n3d ago\n\nFORSUBSCRIBERS\n\n## Inside China’s biggest AI show: Robot police, dancing humanoids and a roof collapse\n\nHundreds of thousands of AI-curious visitors from China and abroad flocked to Shanghai for this weekend’s World Artificial Intelligence Conference.\n\n5d ago [...] BREAKING: An FDA panel votes to ease restrictions on some peptides over agency scientists’ objections\n\nIE 11 is not supported. For an optimal experience visit our site on another browser.\n\n# ARTIFICIAL INTELLIGENCE\n\nThe latest news and top stories on artificial intelligence, including ChatGPT, AI Chatbot and Bard.\n\nAlexander MacDougall / Albany Times Union via Getty Images\n\nARTIFICIAL INTELLIGENCE [...] ## Stay Tuned NOW\n\n## 04:41\n\n### OpenAI says its AI models went rogue and hacked another tech company during test\n\n## Hallie Jackson NOW\n\n## 04:59\n\n### Inside the world of robot fight clubs\n\n## Stay Tuned NOW\n\n## 03:06\n\n### Apple sues OpenAI and two former employees over alleged trade secret theft\n\n## Hallie Jackson NOW\n\n## 02:23\n\n### Would you train robots by recording yourself doing your chores?\n\n## NBC News NOW\n\n## 03:09',
#    'score': 0.63098115,
#    'raw_content': None,
#    'id': '5aac6a-04'}],
#  'response_time': 0.88,
#  'request_id': '3ef9f2a2-f0c7-4854-93ff-0da637514ade'}

# %%
from langchain.tools import tool

@tool("calculator", description="Performs arithmetic calculations. Use this for any math problems.")
def calc(expression: str) -> str:
    """Evaluate mathematical expressions."""
    return str(eval(expression))

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model,
    tools=[tavily_search_tool, calc],
    system_prompt="You are a helpful assistant. Use tools when needed to answer questions."
)

agent

# %%
user_input = "What is the current AI news for anthropic and then calculate 5+5"

for step in agent.stream(
    {"messages": [{"role": "user", "content": user_input}]},
    stream_mode="values"
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is the current AI news for anthropic and then calculate 5+5
# ================================== Ai Message ==================================
#
# I'll search for the latest AI news about Anthropic and calculate 5+5 in parallel.
# Tool Calls:
#   tavily_search (kanz8ddmw)
#  Call ID: kanz8ddmw
#   Args:
#     exclude_domains: []
#     include_domains: []
#     include_images: False
#     query: Anthropic AI latest news
#     search_depth: None
#     time_range: None
#     topic: None
#   calculator (0g114a5dh)
#  Call ID: 0g114a5dh
#   Args:
#     expression: 5+5
# ================================= Tool Message =================================
# Name: calculator
#
# 10
# ================================== Ai Message ==================================
#
# ## Current AI News: Anthropic
#
# Here are the latest developments from Anthropic:
#
# - **Claude Fable 5.1 and Mythos 5.1** — Anthropic has introduced what it describes as the world's most advanced models for coding and knowledge work.
#
# - **Introducing Opus 5** (July 24, 2026) — A step change for the Opus tier, featuring stronger coding, more capable agents, and sharper professional work.
#
# - **Claude Science** (June 30, 2026) — A customizable app that integrates the tools and packages researchers most often use, produces auditable artifacts, and provides flexible access to computing resources.
#
# - **Recursive Self-Improvement** — Claude is getting better at proposing its own experiments. In April 2026, Anthropic published the first demonstration of Claude running an open-ended research project end to end on an AI safety problem. The rate at which AI models improve is accelerating, with task length doubling roughly every four months. On the most open-ended tasks, Claude's success rate reached 76% in May 2026, up 50 percentage points in six months.
#
# - **Claude building the next version of itself** — Anthropic says its AI agent Claude is leading 26% of its model research development, though the company notes Claude is not yet completely autonomous. This has sparked industry debate about the pace of AI development.
#
# - **Threat Intelligence Report** (September 2026) — Anthropic published its most detailed threat intelligence report to date, covering how people tried to misuse Claude for cyberattacks, influence operations, surveillance, biology, and building weapons — and how they disrupted every operation.
#
# - **IPO Filing** — Anthropic filed to go public with a trillion-dollar IPO, reportedly exceeding OpenAI's valuation.
#
# ## Calculation
#
# **5 + 5 = 10**
